# %%
valeur = 123
x = (valeur > 0)

# %%
def max(a, b, c=0):
    if a > b and a > c:
        return a
    elif b > c:
        return b
    else:
        return c

max(5, 3, 4)
# Out:
# 5

# %%
def max(a, b, c=0):
    if a > b and a > c:
        return a
    elif b > c:
        return b
    else:
        return c

print(max(5, 3, 4))
# Out:
# 5

# %%
def max(a, b, c=0):
    if a > b and a > c:
        return a
    elif b > c:
        return b
    else:
        return c

print(max(-5, -3))
# Out:
# 0

# %%
x = 3
chaine = f"La valeur de x est {x}"
x = 2

# %%
chaine = "je vais bien BIEN bieN"
n = chaine.count("bien")
